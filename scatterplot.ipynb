# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import linregress

# %%
# Read CSV
scatterdata = pd.read_csv("scatterplot.csv")
scatterdata.drop(columns= 'Unnamed: 0')
# Out:
#              State  Frequency of Military  Frequency of UFO  Unnamed: 4  \
# 0          Alabama                     26                 6         NaN
# 1           Alaska                     13                 2         NaN
# 2          Arizona                     13                21         NaN
# 3         Arkansas                      4                 4         NaN
# 4       California                     59                65         NaN
# 5         Colorado                      8                13         NaN
# 6      Connecticut                      5                 8         NaN
# 7         Delaware                      3                 0         NaN
# 8               DC                      5                 0         NaN
# 9          Florida                     39                28         NaN
# 10         Georgia                     15                10         NaN
# 11          Hawaii                     27                 2         NaN
# 12           Idaho                      6                 3         NaN
# 13        Illinois                     13                43         NaN
# 14         Indiana                      7                13         NaN
# 15            Iowa                      3                 7         NaN
# 16          Kansas                      7                 6         NaN
# 17        Kentucky                      5                11         NaN
# 18       Louisiana                     11                 2         NaN
# 19           Maine                      7                 7         NaN
# 20        Maryland                     19                 6         NaN
# 21   Massachusetts                      8                11         NaN
# 22        Michigan                      6                22         NaN
# 23       Minnesota                      9                14         NaN
# 24     Mississippi                     10                 2         NaN
# 25        Missouri                      9                15         NaN
# 26         Montana                      4                 1         NaN
# 27        Nebraska                      7                 2         NaN
# 28          Nevada                     12                11         NaN
# 29   New Hampshire                      3                 7         NaN
# 30      New Jersey                      6                 9         NaN
# 31      New Mexico                      6                 8         NaN
# 32        New York                     15                47         NaN
# 33  North Carolina                     11                13         NaN
# 34    North Dakota                      7                 0         NaN
# 35            Ohio                     12                23         NaN
# 36        Oklahoma                     14                 6         NaN
# 37          Oregon                      9                20         NaN
# 38    Pennsylvania                     10                14         NaN
# 39     Puerto Rico                      0                 1         NaN
# 40    Rhode Island                      3                 2         NaN
# 41  South Carolina                     12                 7         NaN
# 42       Tennessee                      7                13         NaN
# 43           Texas                     31                29         NaN
# 44            Utah                      8                 4         NaN
# 45         Vermont                      5                 2         NaN
# 46        Virginia                     36                13         NaN
# 47      Washington                     18                33         NaN
# 48   West Virginia                      6                 5         NaN
# 49       Wisconsin                      7                10         NaN
# 50         Wyoming                      2                 0         NaN
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# 23         NaN         NaN         NaN
# 24         NaN         NaN         NaN
# 25         NaN         NaN         NaN
# 26         NaN         NaN         NaN
# 27         NaN         NaN         NaN
# 28         NaN         NaN         NaN
# 29         NaN         NaN         NaN
# 30         NaN         NaN         NaN
# 31         NaN         NaN         NaN
# 32         NaN         NaN         NaN
# 33         NaN         NaN         NaN
# 34         NaN         NaN         NaN
# 35         NaN         NaN         NaN
# 36         NaN         NaN         NaN
# 37         NaN         NaN         NaN
# 38         NaN         NaN         NaN
# 39         NaN         NaN         NaN
# 40         NaN         NaN         NaN
# 41         NaN         NaN         NaN
# 42         NaN         NaN         NaN
# 43         NaN         NaN         NaN
# 44         NaN         NaN         NaN
# 45         NaN         NaN         NaN
# 46         NaN         NaN         NaN
# 47         NaN         NaN         NaN
# 48         NaN         NaN         NaN
# 49         NaN         NaN         NaN
# 50         NaN         NaN         NaN

# %%
scatterdata.plot(kind="scatter", x="Frequency of Military", y="Frequency of UFO", grid=True, figsize=(8,8),
              title="Frequency of UFO sightings Vs. Frequency of Military Bases")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
(slope, intercept, _, _, _)= linregress(scatterdata['Frequency of Military'], scatterdata['Frequency of UFO'])

fit = slope * scatterdata['Frequency of Military'] + intercept

# %%
fig, ax = plt.subplots()
ax.plot(scatterdata['Frequency of Military'], scatterdata['Frequency of UFO'], linewidth=0, marker = 'o')
ax.plot(scatterdata['Frequency of Military'], fit, 'b--')
ax.set_xlabel("Frequency of Military Bases")
ax.set_ylabel("Frequency of UFO Sightings")
fig.suptitle("Military Base Location vs UFO Sightings", fontsize=16, fontweight="bold")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0.98, 'Military Base Location vs UFO Sightings')
