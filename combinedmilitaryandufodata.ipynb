# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV

mb = pd.read_csv("Military_Clean.csv")
ufo= pd.read_csv("ufo_clean.csv")
combined_data = pd.merge(mb, ufo)
combined_data['state'].replace(
    to_replace=['tx'],
    value='Texas',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['hi'],
    value='Hawaii',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['tn'],
    value='Tennessee',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ct'],
    value='Connecticut',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['al'],
    value='Alabama',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ak'],
    value='Alaska',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['az'],
    value='Arizona',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ar'],
    value='Arkansas',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ca'],
    value='California',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['co'],
    value='Colordo',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['de'],
    value='Delaware',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['tx'],
    value='Texas',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['fl'],
    value='Florida',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ga'],
    value='Georgia',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['id'],
    value='Idaho',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['il'],
    value='Illinios',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['in'],
    value='Indiana',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ia'],
    value='Iowa',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ks'],
    value='Kansas',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ky'],
    value='Kentucky',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['la'],
    value='Louisiana',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['me'],
    value='Maine',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['mi'],
    value='Michigan',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['md'],
    value='Maryland',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ma'],
    value='Massachusetts',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['mn'],
    value='Minnesota',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ms'],
    value='Mississippi',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['mo'],
    value='Missouri',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['mt'],
    value='Montana',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ne'],
    value='Nebraska',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['nh'],
    value='New Hampshire',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['nj'],
    value='New Jersey',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['tx'],
    value='Texas',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['nm'],
    value='New Mexico',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ny'],
    value='New York',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['nc'],
    value='North Carolina',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['nd'],
    value='North Dakota',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['oh'],
    value='Ohio',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ok'],
    value='Oklahoma',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['or'],
    value='Oregon',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['pa'],
    value='Pennsylvania',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ri'],
    value='Rhode Island',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['ut'],
    value='Utah',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['vt'],
    value='Vermont',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['va'],
    value='Virginia',
    inplace=True
)
f
combined_data['state'].replace(
    to_replace=['wv'],
    value='West Virginia',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['wi'],
    value='Wisconsin',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['wy'],
    value='Wyoming',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['nv'],
    value='Nevada',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['pr'],
    value='Puerto Rico',
    inplace=True
)
combined_data['state'].replace(
    to_replace=['sc'],
    value='South Carolina',
    inplace=True
)
combined_data
# Out:
#      Unnamed: 0  OBJECTID_1  OBJECTID     COMPONENT  \
# 0             0           1         1   Army Active
# 1             3           4         4   Army Active
# 2             4           5         6   Army Active
# 3             5           6         9   Army Active
# 4             7           8        12   Army Active
# 5             8           9        13   Army Active
# 6             9          10        14   Army Active
# 7            10          11        27  Army Reserve
# 8            11          12        41   Army Active
# 9            12          13        43   Army Active
# 10           13          14        44   Army Active
# 11           14          15        46   Army Active
# 12           15          16        49  Army Reserve
# 13           16          17        50   Army Active
# 14           17          18        51   Army Active
# 15           19          20        53   Army Active
# 16           21          22        60   Army Active
# ...

# %%
# Create a group based on the values in the 'maker' column
military_state = combined_data.groupby('STATE_TERR')

# Count how many times each maker appears in our group
military_count = military_state['STATE_TERR'].count()

military_count
# Out:
# STATE_TERR
# Alabama                 26
# Alaska                  13
# Arizona                 13
# Arkansas                 4
# California              59
# Colorado                 8
# Connecticut              5
# Delaware                 3
# District of Columbia     5
# Florida                 39
# Georgia                 15
# Hawaii                  27
# Idaho                    6
# Illinois                13
# Indiana                  7
# Iowa                     3
# Kansas                   7
# Kentucky                 5
# Louisiana               11
# Maine                    7
# Maryland                19
# Massachusetts            8
# Michigan                 6
# Minnesota                9
# Mississippi             10
# Missouri                 9
# Montana                  4
# Nebraska                 7
# Nevada                  12
# New Hampshire            3
# New Jersey               6
# New Mexico               6
# New York                15
# North Carolina          11
# ...

# %%
# Create a group based on the values in the 'maker' column
ufo_state = combined_data.groupby('state')

# Count how many times each maker appears in our group
ufo_count = ufo_state['state'].count()

ufo_count
# Out:
# state
# Alabama            6
# Alaska             2
# Arizona           21
# Arkansas           4
# California        65
# Colordo           13
# Connecticut        8
# Florida           28
# Georgia           10
# Hawaii             2
# Idaho              3
# Illinios          43
# Indiana           13
# Iowa               7
# Kansas             6
# Kentucky          11
# Louisiana          2
# Maine              7
# Maryland           6
# Massachusetts     11
# Michigan          22
# Minnesota         14
# Mississippi        2
# Missouri          15
# Montana            1
# Nebraska           2
# Nevada            11
# New Hampshire      7
# New Jersey         9
# New Mexico         8
# New York          47
# North Carolina    13
# Ohio              23
# Oklahoma           6
# Oregon            20
# Pennsylvania      14
# Puerto Rico        1
# Rhode Island       2
# South Carolina     7
# Tennessee         13
# Texas             29
# Utah               4
# Vermont            2
# ...

# %%
df_all_rows = pd.concat([ufo_count, military_count])
df_all_rows
# Out:
# Alabama            6
# Alaska             2
# Arizona           21
# Arkansas           4
# California        65
# Colordo           13
# Connecticut        8
# Florida           28
# Georgia           10
# Hawaii             2
# Idaho              3
# Illinios          43
# Indiana           13
# Iowa               7
# Kansas             6
# Kentucky          11
# Louisiana          2
# Maine              7
# Maryland           6
# Massachusetts     11
# Michigan          22
# Minnesota         14
# Mississippi        2
# Missouri          15
# Montana            1
# Nebraska           2
# Nevada            11
# New Hampshire      7
# New Jersey         9
# New Mexico         8
#                   ..
# Massachusetts      8
# Michigan           6
# Minnesota          9
# Mississippi       10
# Missouri           9
# Montana            4
# Nebraska           7
# Nevada            12
# New Hampshire      3
# New Jersey         6
# New Mexico         6
# New York          15
# ...
